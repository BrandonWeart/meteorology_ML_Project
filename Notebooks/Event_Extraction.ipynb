# %% [markdown]
# # Valid dates
#
# ### The GEFS data has missing dates. This returns me a list of dates that are present in the GEFS data to avoid errors.

# %%
import os
import pandas as pd

def generate_labeled_dates(
    nc_dir: str,
    tornado_csv: str,
    date_lower: str = '2001-01-01',
    date_upper: str = '2019-12-31',
    exclusion_dates: list = None,
    label0_step: int = 20,
    label1_step: int = 2,
    output_csv: str = 'all_labeled_dates.csv'
) -> pd.DataFrame:
    """
    Create and save a balanced set of dates labeled 0/1/2 for no/weak/strong tornado activity.

    Parameters
    ----------
    nc_dir : str
        Directory of NetCDF files named 'YYYYMMDDHHMM_daily_preproc_ml.nc'.
    tornado_csv : str
        CSV with tornado records ('slat','slon','mag','date').
    date_lower, date_upper : str
        Inclusive date range in 'YYYY-MM-DD'.
    exclusion_dates : list of str
        Dates to drop, default ['2011-04-27','2023-03-31','1974-04-04'].
    label0_step, label1_step : int
        Sampling intervals for classes 0 and 1.
    output_csv : str
        Path to write the labeled CSV.

    Returns
    -------
    pd.DataFrame
        ['date','classification'] for classes 0,1,2.
    """
    # 1) dates with model data
    files = [f for f in os.listdir(nc_dir) if f.endswith('_daily_preproc_ml.nc')]
    available = {
        pd.to_datetime(f.split('_')[0], format='%Y%m%d%H%M').date() for f in files
    }

    # 2) load & filter tornado data
    tor = pd.read_csv(tornado_csv)
    tor['day'] = pd.to_datetime(tor['date'], errors='coerce').dt.date
    low, high = pd.to_datetime(date_lower).date(), pd.to_datetime(date_upper).date()
    tor = tor[(tor['slat'].between(30,36)) & (tor['slon'].between(-93,-80)) &
              (tor['day'].between(low, high))]

    # 3) label days with tornadoes
    label1, label2 = [], []
    for day, grp in tor.groupby('day'):
        if day not in available: continue
        if grp['mag'].ge(2).any(): label2.append(day)
        elif grp['mag'].le(1).all(): label1.append(day)

    # 4) label no-tornado days
    all_days = pd.date_range(low, high).date
    present = set(tor['day'])
    label0 = [d for d in all_days if d in available and d not in present]

    # 5) exclude dates
    excl = {pd.to_datetime(d).date() for d in (exclusion_dates or
            ['2011-04-27','2023-03-31','1974-04-04'])}
    label0 = [d for d in label0 if d not in excl]
    label1 = [d for d in label1 if d not in excl]
    label2 = [d for d in label2 if d not in excl]

    # 6) subsample
    samp0 = sorted(label0)[::label0_step]
    samp1 = sorted(label1)[::label1_step]
    samp2 = sorted(label2)

    # 7) build & save DataFrame
    def df_from(dates, cls):
        return pd.DataFrame({'date':[d.isoformat() for d in dates],
                             'classification':cls})

    out = pd.concat([df_from(samp0,0), df_from(samp1,1), df_from(samp2,2)],
                    ignore_index=True)
    out.to_csv(output_csv, index=False)

    print(f"Samples: 0→{len(samp0)}, 1→{len(samp1)}, 2→{len(samp2)}")
    return out

labeled_df = generate_labeled_dates(
    nc_dir='/home/scratch/ahaberlie1/gefs_reforecast_preproc/',
    tornado_csv='/home/z1995995/data_science_for_the_geosciences/495/1950-2023_actual_tornadoes.csv',
    output_csv='all_labeled_dates.csv'
)
print(labeled_df.head())
# Out:
# No-tornado days sampled: 259
# Weak-tornado days sampled: 256
# Strong-tornado days sampled: 197

# %% [markdown]
# # Event Extraction

# %%
import os
import numpy as np
import pandas as pd
import xarray as xr

def generate_event_metrics(
    tornado_csv: str,
    labeled_dates_csv: str,
    reforecast_dir: str,
    output_csv: str,
    init_index: int = 4
) -> None:
    """
    Generate and append tornado event metrics from GEFS reforecast datasets.

    Parameters
    ----------
    tornado_csv : str
        Path to the CSV file containing tornado observations with columns
        'slat', 'slon', 'mag', and 'date'.
    labeled_dates_csv : str
        Path to the CSV file containing dates to process, with a 'date'
        column formatted as YYYY-MM-DD.
    reforecast_dir : str
        Directory containing preprocessed GEFS reforecast NetCDF files named
        as YYYYMMDD1200_daily_preproc_ml.nc.
    output_csv : str
        Path to the output CSV file where metrics will be appended.
    init_index : int, optional
        Initialization index to select along the 'init' dimension
        (default is 4).
    """
    tor_df = pd.read_csv(tornado_csv)
    label_ds = pd.read_csv(labeled_dates_csv)

    for date in label_ds['date']:
        date_rfm = date.replace('-', '')
        ds_path = os.path.join(reforecast_dir, f"{date_rfm}1200_daily_preproc_ml.nc")
        ds = xr.open_dataset(ds_path)

        # subset tornado reports to Dixie Alley
        tor_dixie = tor_df[
            (tor_df['slat'] >= 30) & (tor_df['slat'] <= 36) &
            (tor_df['slon'] >= -93) & (tor_df['slon'] <= -80)
        ]
        sigtor_dixie = tor_dixie[tor_dixie['mag'] >= 2]
        tor_day_dixie = tor_dixie[(tor_dixie['mag'] >= 0) & (tor_dixie['mag'] < 2)]

        # subset dataset to Dixie Alley region
        ds = ds.where(
            (ds.lat >= 30) & (ds.lat <= 36) &
            (ds.lon >= -93) & (ds.lon <= -80),
            drop=True
        )

        # assign class label
        if date in sigtor_dixie['date'].values:
            ds['class'] = 2
        elif date in tor_day_dixie['date'].values:
            ds['class'] = 1
        else:
            ds['class'] = 0

        # drop unused variables
        ds = ds.drop_vars([
            'prec', 'ship', 'z500', 'lapse57', 'mucape', 'frzlvl', 'ulcape', 'mlcape'
        ])

        # select the requested initialization slice
        ds = ds.isel(init=init_index)

        # compute metrics
        metrics = {
            "date": date,
            # sums
            "u10_sum":     float(ds.u10.max(dim="time").sum()),
            "v10_sum":     float(ds.v10.max(dim="time").sum()),
            "t2m_sum":     float(ds.t2m.max(dim="time").sum()),
            "td2m_sum":    float(ds.td2m.max(dim="time").sum()),
            "cprec_sum":   float(ds.cprec.max(dim="time").sum()),
            "srh500m_sum": float(ds.srh500m.max(dim="time").sum()),
            "srh1km_sum":  float(ds.srh1km.max(dim="time").sum()),
            "srh3km_sum":  float(ds.srh3km.max(dim="time").sum()),
            "scp_sum":     float(ds.scp.max(dim="time").sum()),
            "stp_sum":     float(ds.stp.max(dim="time").sum()),
            "vtp_sum":     float(ds.vtp.max(dim="time").sum()),
            "lcl_sum":     float(ds.lcl.max(dim="time").sum()),
            "shear6km_sum":float(ds.shear6km.max(dim="time").sum()),
            "mslp_sum":    float(ds.mslp.max(dim="time").sum()),
            "pwat_sum":    float(ds.pwat.max(dim="time").sum()),
            "sbcape_sum":  float(ds.sbcape_gfs.max(dim="time").sum()),
            "sbcin_sum":   float(ds.sbcin_gfs.max(dim="time").sum()),

            # medians
            "u10_median":     float(ds.u10.max(dim="time").median()),
            "v10_median":     float(ds.v10.max(dim="time").median()),
            "t2m_median":     float(ds.t2m.max(dim="time").median()),
            "td2m_median":    float(ds.td2m.max(dim="time").median()),
            "cprec_median":   float(ds.cprec.max(dim="time").median()),
            "srh500m_median": float(ds.srh500m.max(dim="time").median()),
            "srh1km_median":  float(ds.srh1km.max(dim="time").median()),
            "srh3km_median":  float(ds.srh3km.max(dim="time").median()),
            "scp_median":     float(ds.scp.max(dim="time").median()),
            "stp_median":     float(ds.stp.max(dim="time").median()),
            "vtp_median":     float(ds.vtp.max(dim="time").median()),
            "lcl_median":     float(ds.lcl.max(dim="time").median()),
            "shear6km_median":float(ds.shear6km.max(dim="time").median()),
            "mslp_median":    float(ds.mslp.max(dim="time").median()),
            "pwat_median":    float(ds.pwat.max(dim="time").median()),
            "sbcape_median":  float(ds.sbcape_gfs.max(dim="time").median()),
            "sbcin_median":   float(ds.sbcin_gfs.max(dim="time").median()),

            # max values
            "u10_max":     float(ds.u10.max(dim="time").max()),
            "v10_max":     float(ds.v10.max(dim="time").max()),
            "t2m_max":     float(ds.t2m.max(dim="time").max()),
            "td2m_max":    float(ds.td2m.max(dim="time").max()),
            "cprec_max":   float(ds.cprec.max(dim="time").max()),
            "srh500m_max": float(ds.srh500m.max(dim="time").max()),
            "srh1km_max":  float(ds.srh1km.max(dim="time").max()),
            "srh3km_max":  float(ds.srh3km.max(dim="time").max()),
            "scp_max":     float(ds.scp.max(dim="time").max()),
            "stp_max":     float(ds.stp.max(dim="time").max()),
            "vtp_max":     float(ds.vtp.max(dim="time").max()),
            "lcl_max":     float(ds.lcl.max(dim="time").max()),
            "shear6km_max":float(ds.shear6km.max(dim="time").max()),
            "mslp_max":    float(ds.mslp.max(dim="time").max()),
            "pwat_max":    float(ds.pwat.max(dim="time").max()),
            "sbcape_max":  float(ds.sbcape_gfs.max(dim="time").max()),
            "sbcin_max":   float(ds.sbcin_gfs.max(dim="time").max()),

            "classification": int(ds['class'])
        }

        metric_df = pd.DataFrame([metrics])
        write_header = not os.path.exists(output_csv)
        metric_df.to_csv(
            output_csv,
            mode='a',
            header=write_header,
            index=False
        )
        print(f"Successfully added {date}, classification {int(ds['class'])}")

    print("Finished processing all dates.")

if __name__ == "__main__":
    generate_event_metrics(
        tornado_csv="/home/z1995995/data_science_for_the_geosciences/495/1950-2023_actual_tornadoes.csv",
        labeled_dates_csv="all_labeled_dates.csv",
        reforecast_dir="/home/scratch/ahaberlie1/gefs_reforecast_preproc",
        output_csv="/home/scratch/BWEART2/tor_RF_event_values_shorts.csv",
        init_index=4
    )
# Out:
# Succesfully Added 2001-01-01, with classification 0
# Succesfully Added 2001-01-26, with classification 0
# Succesfully Added 2001-02-21, with classification 0
# Succesfully Added 2001-03-22, with classification 0
# Succesfully Added 2001-04-15, with classification 0
# Succesfully Added 2001-05-09, with classification 0
# Succesfully Added 2001-06-14, with classification 0
# Succesfully Added 2001-07-11, with classification 0
# Succesfully Added 2001-08-03, with classification 0
# Succesfully Added 2001-08-27, with classification 0
# Succesfully Added 2001-09-23, with classification 0
# Succesfully Added 2001-10-19, with classification 0
# Succesfully Added 2001-11-12, with classification 0
# Succesfully Added 2001-12-15, with classification 0
# Succesfully Added 2002-01-10, with classification 0
# Succesfully Added 2002-02-03, with classification 0
# Succesfully Added 2002-02-27, with classification 0
# Succesfully Added 2002-03-25, with classification 0
# Succesfully Added 2002-04-19, with classification 0
# Succesfully Added 2002-05-18, with classification 0
# Succesfully Added 2002-06-12, with classification 0
# Succesfully Added 2002-07-06, with classification 0
# Succesfully Added 2002-08-01, with classification 0
# Succesfully Added 2002-08-24, with classification 0
# Succesfully Added 2002-09-20, with classification 0
# Succesfully Added 2002-10-25, with classification 0
# Succesfully Added 2002-11-22, with classification 0
# Succesfully Added 2002-12-15, with classification 0
# Succesfully Added 2003-01-11, with classification 0
# Succesfully Added 2003-02-03, with classification 0
# Succesfully Added 2003-03-03, with classification 0
# Succesfully Added 2003-03-30, with classification 0
# Succesfully Added 2003-04-28, with classification 0
# Succesfully Added 2003-06-05, with classification 0
# Succesfully Added 2003-06-29, with classification 0
# Succesfully Added 2003-07-26, with classification 0
# Succesfully Added 2003-08-20, with classification 0
# Succesfully Added 2003-09-13, with classification 0
# Succesfully Added 2003-10-06, with classification 0
# Succesfully Added 2003-10-31, with classification 0
# Succesfully Added 2003-11-24, with classification 0
# Succesfully Added 2003-12-19, with classification 0
# Succesfully Added 2004-01-11, with classification 0
# Succesfully Added 2004-02-07, with classification 0
# Succesfully Added 2004-03-01, with classification 0
# Succesfully Added 2004-03-29, with classification 0
# Succesfully Added 2004-04-25, with classification 0
# Succesfully Added 2004-05-22, with classification 0
# Succesfully Added 2004-06-24, with classification 0
# Succesfully Added 2004-07-21, with classification 0
# Succesfully Added 2004-08-16, with classification 0
# Succesfully Added 2004-09-12, with classification 0
# Succesfully Added 2004-10-11, with classification 0
# Succesfully Added 2004-11-26, with classification 0
# Succesfully Added 2004-12-24, with classification 0
# Succesfully Added 2005-01-21, with classification 0
# Succesfully Added 2005-02-13, with classification 0
# Succesfully Added 2005-03-10, with classification 0
# Succesfully Added 2005-04-04, with classification 0
# Succesfully Added 2005-05-05, with classification 0
# Succesfully Added 2005-05-30, with classification 0
# Succesfully Added 2005-06-26, with classification 0
# Succesfully Added 2005-07-28, with classification 0
# Succesfully Added 2005-08-20, with classification 0
# Succesfully Added 2005-09-15, with classification 0
# Succesfully Added 2005-10-13, with classification 0
# Succesfully Added 2005-11-05, with classification 0
# Succesfully Added 2005-12-02, with classification 0
# Succesfully Added 2005-12-31, with classification 0
# Succesfully Added 2006-01-27, with classification 0
# Succesfully Added 2006-03-04, with classification 0
# Succesfully Added 2006-04-10, with classification 0
# Succesfully Added 2006-05-12, with classification 0
# Succesfully Added 2006-06-18, with classification 0
# Succesfully Added 2006-07-30, with classification 0
# Succesfully Added 2006-08-24, with classification 0
# Succesfully Added 2006-09-17, with classification 0
# Succesfully Added 2006-10-14, with classification 0
# Succesfully Added 2006-11-10, with classification 0
# Succesfully Added 2006-12-07, with classification 0
# Succesfully Added 2007-01-03, with classification 0
# Succesfully Added 2007-01-29, with classification 0
# Succesfully Added 2007-02-22, with classification 0
# Succesfully Added 2007-03-21, with classification 0
# Succesfully Added 2007-04-16, with classification 0
# Succesfully Added 2007-05-11, with classification 0
# Succesfully Added 2007-06-03, with classification 0
# Succesfully Added 2007-06-30, with classification 0
# Succesfully Added 2007-07-27, with classification 0
# Succesfully Added 2007-08-19, with classification 0
# Succesfully Added 2007-09-12, with classification 0
# Succesfully Added 2007-10-10, with classification 0
# Succesfully Added 2007-11-05, with classification 0
# Succesfully Added 2007-11-30, with classification 0
# Succesfully Added 2007-12-26, with classification 0
# Succesfully Added 2008-01-20, with classification 0
# Succesfully Added 2008-02-14, with classification 0
# Succesfully Added 2008-03-17, with classification 0
# Succesfully Added 2008-04-14, with classification 0
# Succesfully Added 2008-05-19, with classification 0
# Succesfully Added 2008-06-12, with classification 0
# Succesfully Added 2008-07-09, with classification 0
# Succesfully Added 2008-08-01, with classification 0
# Succesfully Added 2008-08-31, with classification 0
# Succesfully Added 2008-09-28, with classification 0
# Succesfully Added 2008-10-25, with classification 0
# Succesfully Added 2008-11-19, with classification 0
# Succesfully Added 2008-12-14, with classification 0
# Succesfully Added 2009-01-11, with classification 0
# Succesfully Added 2009-02-04, with classification 0
# Succesfully Added 2009-03-04, with classification 0
# Succesfully Added 2009-04-03, with classification 0
# Succesfully Added 2009-05-11, with classification 0
# Succesfully Added 2009-06-08, with classification 0
# Succesfully Added 2009-07-08, with classification 0
# Succesfully Added 2009-08-01, with classification 0
# Succesfully Added 2009-08-24, with classification 0
# Succesfully Added 2009-09-19, with classification 0
# Succesfully Added 2009-10-16, with classification 0
# Succesfully Added 2009-11-12, with classification 0
# Succesfully Added 2009-12-06, with classification 0
# Succesfully Added 2010-01-02, with classification 0
# Succesfully Added 2010-01-28, with classification 0
# Succesfully Added 2010-02-20, with classification 0
# Succesfully Added 2010-03-19, with classification 0
# Succesfully Added 2010-04-15, with classification 0
# Succesfully Added 2010-05-19, with classification 0
# Succesfully Added 2010-06-12, with classification 0
# Succesfully Added 2010-07-07, with classification 0
# Succesfully Added 2010-08-01, with classification 0
# Succesfully Added 2010-08-26, with classification 0
# Succesfully Added 2010-09-18, with classification 0
# Succesfully Added 2010-10-13, with classification 0
# Succesfully Added 2010-11-10, with classification 0
# Succesfully Added 2010-12-06, with classification 0
# Succesfully Added 2010-12-30, with classification 0
# Succesfully Added 2011-01-24, with classification 0
# Succesfully Added 2011-02-17, with classification 0
# Succesfully Added 2011-03-18, with classification 0
# Succesfully Added 2011-04-21, with classification 0
# Succesfully Added 2011-05-19, with classification 0
# Succesfully Added 2011-06-15, with classification 0
# Succesfully Added 2011-07-11, with classification 0
# Succesfully Added 2011-08-04, with classification 0
# Succesfully Added 2011-08-28, with classification 0
# Succesfully Added 2011-09-26, with classification 0
# Succesfully Added 2011-10-21, with classification 0
# Succesfully Added 2011-11-13, with classification 0
# Succesfully Added 2011-12-08, with classification 0
# Succesfully Added 2012-01-02, with classification 0
# Succesfully Added 2012-02-03, with classification 0
# Succesfully Added 2012-03-05, with classification 0
# Succesfully Added 2012-04-04, with classification 0
# Succesfully Added 2012-04-29, with classification 0
# Succesfully Added 2012-05-26, with classification 0
# Succesfully Added 2012-06-22, with classification 0
# Succesfully Added 2012-07-15, with classification 0
# Succesfully Added 2012-08-12, with classification 0
# Succesfully Added 2012-09-08, with classification 0
# Succesfully Added 2012-10-05, with classification 0
# Succesfully Added 2012-11-01, with classification 0
# Succesfully Added 2012-11-24, with classification 0
# Succesfully Added 2012-12-22, with classification 0
# Succesfully Added 2013-01-17, with classification 0
# Succesfully Added 2013-02-11, with classification 0
# Succesfully Added 2013-03-08, with classification 0
# Succesfully Added 2013-04-01, with classification 0
# Succesfully Added 2013-05-03, with classification 0
# Succesfully Added 2013-05-27, with classification 0
# Succesfully Added 2013-06-28, with classification 0
# Succesfully Added 2013-07-25, with classification 0
# Succesfully Added 2013-08-21, with classification 0
# Succesfully Added 2013-09-13, with classification 0
# Succesfully Added 2013-10-09, with classification 0
# Succesfully Added 2013-11-02, with classification 0
# Succesfully Added 2013-11-27, with classification 0
# Succesfully Added 2013-12-22, with classification 0
# Succesfully Added 2014-01-16, with classification 0
# Succesfully Added 2014-02-09, with classification 0
# Succesfully Added 2014-03-07, with classification 0
# Succesfully Added 2014-03-31, with classification 0
# Succesfully Added 2014-05-01, with classification 0
# Succesfully Added 2014-05-29, with classification 0
# Succesfully Added 2014-06-30, with classification 0
# Succesfully Added 2014-07-25, with classification 0
# Succesfully Added 2014-08-17, with classification 0
# Succesfully Added 2014-09-11, with classification 0
# Succesfully Added 2014-10-09, with classification 0
# Succesfully Added 2014-11-03, with classification 0
# Succesfully Added 2014-11-30, with classification 0
# Succesfully Added 2014-12-26, with classification 0
# Succesfully Added 2015-01-22, with classification 0
# Succesfully Added 2015-02-14, with classification 0
# Succesfully Added 2015-03-09, with classification 0
# Succesfully Added 2015-04-02, with classification 0
# Succesfully Added 2015-05-04, with classification 0
# Succesfully Added 2015-06-03, with classification 0
# Succesfully Added 2015-06-26, with classification 0
# Succesfully Added 2015-07-19, with classification 0
# Succesfully Added 2015-08-13, with classification 0
# Succesfully Added 2015-09-06, with classification 0
# Succesfully Added 2015-10-01, with classification 0
# Succesfully Added 2015-10-24, with classification 0
# Succesfully Added 2015-11-21, with classification 0
# Succesfully Added 2015-12-14, with classification 0
# Succesfully Added 2016-01-14, with classification 0
# Succesfully Added 2016-02-10, with classification 0
# Succesfully Added 2016-03-14, with classification 0
# Succesfully Added 2016-04-17, with classification 0
# Succesfully Added 2016-05-14, with classification 0
# Succesfully Added 2016-06-08, with classification 0
# Succesfully Added 2016-07-07, with classification 0
# Succesfully Added 2016-08-01, with classification 0
# Succesfully Added 2016-08-28, with classification 0
# Succesfully Added 2016-09-22, with classification 0
# Succesfully Added 2016-10-15, with classification 0
# Succesfully Added 2016-11-07, with classification 0
# Succesfully Added 2016-12-03, with classification 0
# Succesfully Added 2016-12-31, with classification 0
# Succesfully Added 2017-01-29, with classification 0
# Succesfully Added 2017-02-23, with classification 0
# Succesfully Added 2017-03-20, with classification 0
# Succesfully Added 2017-04-21, with classification 0
# Succesfully Added 2017-05-25, with classification 0
# Succesfully Added 2017-06-19, with classification 0
# Succesfully Added 2017-07-17, with classification 0
# Succesfully Added 2017-08-12, with classification 0
# Succesfully Added 2017-09-07, with classification 0
# Succesfully Added 2017-10-01, with classification 0
# Succesfully Added 2017-10-29, with classification 0
# Succesfully Added 2017-11-23, with classification 0
# Succesfully Added 2017-12-16, with classification 0
# Succesfully Added 2018-01-10, with classification 0
# Succesfully Added 2018-02-03, with classification 0
# Succesfully Added 2018-03-04, with classification 0
# Succesfully Added 2018-04-04, with classification 0
# Succesfully Added 2018-05-04, with classification 0
# Succesfully Added 2018-05-31, with classification 0
# Succesfully Added 2018-06-29, with classification 0
# Succesfully Added 2018-07-25, with classification 0
# Succesfully Added 2018-08-22, with classification 0
# Succesfully Added 2018-09-16, with classification 0
# Succesfully Added 2018-10-13, with classification 0
# Succesfully Added 2018-11-10, with classification 0
# Succesfully Added 2018-12-08, with classification 0
# Succesfully Added 2019-01-02, with classification 0
# Succesfully Added 2019-01-27, with classification 0
# Succesfully Added 2019-02-21, with classification 0
# Succesfully Added 2019-03-23, with classification 0
# Succesfully Added 2019-04-22, with classification 0
# Succesfully Added 2019-05-26, with classification 0
# Succesfully Added 2019-06-28, with classification 0
# Succesfully Added 2019-07-25, with classification 0
# Succesfully Added 2019-08-18, with classification 0
# Succesfully Added 2019-09-11, with classification 0
# Succesfully Added 2019-10-04, with classification 0
# Succesfully Added 2019-11-01, with classification 0
# Succesfully Added 2019-11-25, with classification 0
# Succesfully Added 2019-12-21, with classification 0
# Succesfully Added 2001-01-19, with classification 1
# Succesfully Added 2001-02-25, with classification 1
# Succesfully Added 2001-03-12, with classification 1
# Succesfully Added 2001-05-20, with classification 1
# Succesfully Added 2001-05-27, with classification 1
# Succesfully Added 2001-05-30, with classification 1
# Succesfully Added 2001-06-07, with classification 1
# Succesfully Added 2001-06-11, with classification 1
# Succesfully Added 2001-06-18, with classification 1
# Succesfully Added 2001-07-04, with classification 1
# Succesfully Added 2001-08-31, with classification 1
# Succesfully Added 2001-09-13, with classification 1
# Succesfully Added 2001-11-23, with classification 1
# Succesfully Added 2001-12-07, with classification 1
# Succesfully Added 2001-12-13, with classification 1
# Succesfully Added 2001-12-22, with classification 1
# Succesfully Added 2002-03-15, with classification 1
# Succesfully Added 2002-03-20, with classification 1
# Succesfully Added 2002-05-01, with classification 1
# Succesfully Added 2002-05-13, with classification 1
# Succesfully Added 2002-06-05, with classification 1
# Succesfully Added 2002-07-14, with classification 1
# Succesfully Added 2002-09-14, with classification 1
# Succesfully Added 2002-09-18, with classification 1
# Succesfully Added 2002-09-25, with classification 1
# Succesfully Added 2002-09-28, with classification 1
# Succesfully Added 2002-10-04, with classification 1
# Succesfully Added 2002-10-14, with classification 1
# Succesfully Added 2002-10-21, with classification 1
# Succesfully Added 2002-12-23, with classification 1
# Succesfully Added 2003-02-16, with classification 1
# Succesfully Added 2003-03-06, with classification 1
# Succesfully Added 2003-04-07, with classification 1
# Succesfully Added 2003-04-25, with classification 1
# Succesfully Added 2003-05-08, with classification 1
# Succesfully Added 2003-05-15, with classification 1
# Succesfully Added 2003-05-31, with classification 1
# Succesfully Added 2003-06-15, with classification 1
# Succesfully Added 2003-07-12, with classification 1
# Succesfully Added 2003-07-30, with classification 1
# Succesfully Added 2003-10-16, with classification 1
# Succesfully Added 2003-11-27, with classification 1
# Succesfully Added 2004-03-05, with classification 1
# Succesfully Added 2004-04-23, with classification 1
# Succesfully Added 2004-04-29, with classification 1
# Succesfully Added 2004-05-02, with classification 1
# Succesfully Added 2004-05-31, with classification 1
# Succesfully Added 2004-06-03, with classification 1
# Succesfully Added 2004-06-13, with classification 1
# Succesfully Added 2004-06-25, with classification 1
# Succesfully Added 2004-07-14, with classification 1
# Succesfully Added 2004-08-15, with classification 1
# Succesfully Added 2004-09-05, with classification 1
# Succesfully Added 2004-09-17, with classification 1
# Succesfully Added 2004-11-01, with classification 1
# Succesfully Added 2004-11-22, with classification 1
# Succesfully Added 2004-12-22, with classification 1
# Succesfully Added 2005-03-13, with classification 1
# Succesfully Added 2005-04-11, with classification 1
# Succesfully Added 2005-04-23, with classification 1
# Succesfully Added 2005-04-30, with classification 1
# Succesfully Added 2005-05-29, with classification 1
# Succesfully Added 2005-06-11, with classification 1
# Succesfully Added 2005-07-03, with classification 1
# Succesfully Added 2005-07-10, with classification 1
# Succesfully Added 2005-07-13, with classification 1
# Succesfully Added 2005-09-26, with classification 1
# Succesfully Added 2005-11-14, with classification 1
# Succesfully Added 2005-12-03, with classification 1
# Succesfully Added 2005-12-24, with classification 1
# Succesfully Added 2006-01-01, with classification 1
# Succesfully Added 2006-02-02, with classification 1
# Succesfully Added 2006-03-13, with classification 1
# Succesfully Added 2006-04-21, with classification 1
# Succesfully Added 2006-04-26, with classification 1
# Succesfully Added 2006-05-07, with classification 1
# Succesfully Added 2006-05-14, with classification 1
# Succesfully Added 2006-06-17, with classification 1
# Succesfully Added 2006-07-29, with classification 1
# Succesfully Added 2006-09-21, with classification 1
# Succesfully Added 2006-10-16, with classification 1
# Succesfully Added 2006-10-27, with classification 1
# Succesfully Added 2006-11-30, with classification 1
# Succesfully Added 2007-01-04, with classification 1
# Succesfully Added 2007-04-11, with classification 1
# Succesfully Added 2007-06-11, with classification 1
# Succesfully Added 2007-06-18, with classification 1
# Succesfully Added 2007-07-07, with classification 1
# Succesfully Added 2007-09-13, with classification 1
# Succesfully Added 2007-09-20, with classification 1
# Succesfully Added 2007-10-17, with classification 1
# Succesfully Added 2007-10-22, with classification 1
# Succesfully Added 2008-02-16, with classification 1
# Succesfully Added 2008-02-21, with classification 1
# Succesfully Added 2008-04-18, with classification 1
# Succesfully Added 2008-04-28, with classification 1
# Succesfully Added 2008-06-19, with classification 1
# Succesfully Added 2008-06-29, with classification 1
# Succesfully Added 2008-08-18, with classification 1
# Succesfully Added 2008-08-23, with classification 1
# Succesfully Added 2008-09-01, with classification 1
# Succesfully Added 2008-10-08, with classification 1
# Succesfully Added 2008-10-24, with classification 1
# Succesfully Added 2008-12-11, with classification 1
# Succesfully Added 2009-01-03, with classification 1
# Succesfully Added 2009-01-10, with classification 1
# Succesfully Added 2009-03-15, with classification 1
# Succesfully Added 2009-03-27, with classification 1
# Succesfully Added 2009-04-02, with classification 1
# Succesfully Added 2009-04-18, with classification 1
# Succesfully Added 2009-05-01, with classification 1
# Succesfully Added 2009-05-04, with classification 1
# Succesfully Added 2009-05-10, with classification 1
# Succesfully Added 2009-05-23, with classification 1
# Succesfully Added 2009-06-04, with classification 1
# Succesfully Added 2009-06-26, with classification 1
# Succesfully Added 2009-06-28, with classification 1
# Succesfully Added 2009-09-16, with classification 1
# Succesfully Added 2009-10-09, with classification 1
# Succesfully Added 2009-10-22, with classification 1
# Succesfully Added 2009-12-09, with classification 1
# Succesfully Added 2010-01-20, with classification 1
# Succesfully Added 2010-03-12, with classification 1
# Succesfully Added 2010-04-08, with classification 1
# Succesfully Added 2010-05-01, with classification 1
# Succesfully Added 2010-05-15, with classification 1
# Succesfully Added 2010-05-20, with classification 1
# Succesfully Added 2010-07-11, with classification 1
# Succesfully Added 2010-08-06, with classification 1
# Succesfully Added 2010-10-24, with classification 1
# Succesfully Added 2010-11-03, with classification 1
# Succesfully Added 2010-11-26, with classification 1
# Succesfully Added 2011-03-19, with classification 1
# Succesfully Added 2011-04-09, with classification 1
# Succesfully Added 2011-04-16, with classification 1
# Succesfully Added 2011-04-28, with classification 1
# Succesfully Added 2011-05-20, with classification 1
# Succesfully Added 2011-06-22, with classification 1
# Succesfully Added 2011-08-18, with classification 1
# Succesfully Added 2011-09-04, with classification 1
# Succesfully Added 2011-09-19, with classification 1
# Succesfully Added 2011-10-10, with classification 1
# Succesfully Added 2012-01-21, with classification 1
# Succesfully Added 2012-01-26, with classification 1
# Succesfully Added 2012-02-18, with classification 1
# Succesfully Added 2012-02-29, with classification 1
# Succesfully Added 2012-03-11, with classification 1
# Succesfully Added 2012-03-23, with classification 1
# Succesfully Added 2012-04-15, with classification 1
# Succesfully Added 2012-05-13, with classification 1
# Succesfully Added 2012-06-04, with classification 1
# Succesfully Added 2012-06-11, with classification 1
# Succesfully Added 2012-07-29, with classification 1
# Succesfully Added 2012-08-09, with classification 1
# Succesfully Added 2012-08-29, with classification 1
# Succesfully Added 2012-09-30, with classification 1
# Succesfully Added 2012-10-14, with classification 1
# Succesfully Added 2012-12-09, with classification 1
# Succesfully Added 2012-12-17, with classification 1
# Succesfully Added 2013-01-10, with classification 1
# Succesfully Added 2013-04-18, with classification 1
# Succesfully Added 2013-04-28, with classification 1
# Succesfully Added 2013-05-30, with classification 1
# Succesfully Added 2013-06-02, with classification 1
# Succesfully Added 2013-06-09, with classification 1
# Succesfully Added 2013-06-13, with classification 1
# Succesfully Added 2013-07-13, with classification 1
# Succesfully Added 2013-07-31, with classification 1
# Succesfully Added 2013-08-18, with classification 1
# Succesfully Added 2013-10-31, with classification 1
# Succesfully Added 2013-12-20, with classification 1
# Succesfully Added 2014-02-20, with classification 1
# Succesfully Added 2014-04-04, with classification 1
# Succesfully Added 2014-04-30, with classification 1
# Succesfully Added 2014-05-14, with classification 1
# Succesfully Added 2014-05-28, with classification 1
# Succesfully Added 2014-06-05, with classification 1
# Succesfully Added 2014-06-07, with classification 1
# Succesfully Added 2014-06-12, with classification 1
# Succesfully Added 2014-06-27, with classification 1
# Succesfully Added 2014-09-07, with classification 1
# Succesfully Added 2014-10-02, with classification 1
# Succesfully Added 2014-10-06, with classification 1
# Succesfully Added 2014-11-16, with classification 1
# Succesfully Added 2014-12-15, with classification 1
# Succesfully Added 2015-04-03, with classification 1
# Succesfully Added 2015-04-18, with classification 1
# Succesfully Added 2015-04-24, with classification 1
# Succesfully Added 2015-04-27, with classification 1
# Succesfully Added 2015-05-17, with classification 1
# Succesfully Added 2015-05-25, with classification 1
# Succesfully Added 2015-08-06, with classification 1
# Succesfully Added 2015-10-31, with classification 1
# Succesfully Added 2015-11-02, with classification 1
# Succesfully Added 2015-12-21, with classification 1
# Succesfully Added 2015-12-27, with classification 1
# Succesfully Added 2016-02-03, with classification 1
# Succesfully Added 2016-03-10, with classification 1
# Succesfully Added 2016-03-24, with classification 1
# Succesfully Added 2016-03-30, with classification 1
# Succesfully Added 2016-04-29, with classification 1
# Succesfully Added 2016-05-09, with classification 1
# Succesfully Added 2016-06-26, with classification 1
# Succesfully Added 2016-07-10, with classification 1
# Succesfully Added 2016-08-04, with classification 1
# Succesfully Added 2016-08-19, with classification 0
# Succesfully Added 2016-11-28, with classification 1
# Succesfully Added 2016-12-17, with classification 1
# Succesfully Added 2016-12-29, with classification 1
# Succesfully Added 2017-03-01, with classification 1
# Succesfully Added 2017-03-27, with classification 1
# Succesfully Added 2017-04-22, with classification 1
# Succesfully Added 2017-04-29, with classification 1
# Succesfully Added 2017-05-04, with classification 1
# Succesfully Added 2017-05-28, with classification 1
# Succesfully Added 2017-06-21, with classification 1
# Succesfully Added 2017-07-03, with classification 1
# Succesfully Added 2017-07-27, with classification 1
# Succesfully Added 2017-08-30, with classification 1
# Succesfully Added 2017-10-07, with classification 1
# Succesfully Added 2017-11-18, with classification 1
# Succesfully Added 2018-01-22, with classification 1
# Succesfully Added 2018-02-10, with classification 1
# Succesfully Added 2018-02-24, with classification 1
# Succesfully Added 2018-03-05, with classification 1
# Succesfully Added 2018-03-28, with classification 1
# Succesfully Added 2018-04-06, with classification 1
# Succesfully Added 2018-04-22, with classification 1
# Succesfully Added 2018-05-24, with classification 1
# Succesfully Added 2018-06-13, with classification 1
# Succesfully Added 2018-06-18, with classification 1
# Succesfully Added 2018-07-21, with classification 1
# Succesfully Added 2018-07-27, with classification 1
# Succesfully Added 2018-08-02, with classification 1
# Succesfully Added 2018-09-05, with classification 1
# Succesfully Added 2018-09-24, with classification 1
# Succesfully Added 2018-10-11, with classification 1
# Succesfully Added 2018-11-12, with classification 1
# Succesfully Added 2018-12-03, with classification 1
# Succesfully Added 2019-01-04, with classification 1
# Succesfully Added 2019-02-24, with classification 1
# Succesfully Added 2019-03-09, with classification 1
# Succesfully Added 2019-04-08, with classification 1
# Succesfully Added 2019-05-02, with classification 1
# Succesfully Added 2019-05-08, with classification 1
# Succesfully Added 2019-05-11, with classification 1
# Succesfully Added 2019-05-18, with classification 1
# Succesfully Added 2019-06-05, with classification 1
# Succesfully Added 2019-06-08, with classification 1
# Succesfully Added 2019-06-19, with classification 1
# Succesfully Added 2019-06-24, with classification 1
# Succesfully Added 2019-07-14, with classification 1
# Succesfully Added 2019-08-09, with classification 1
# Succesfully Added 2019-10-21, with classification 1
# Succesfully Added 2019-10-31, with classification 1
# Succesfully Added 2019-11-27, with classification 1
# Succesfully Added 2001-02-16, with classification 2
# Succesfully Added 2001-02-24, with classification 2
# Succesfully Added 2001-03-15, with classification 2
# Succesfully Added 2001-05-31, with classification 2
# Succesfully Added 2001-10-13, with classification 2
# Succesfully Added 2001-10-24, with classification 2
# Succesfully Added 2001-11-24, with classification 2
# Succesfully Added 2001-11-26, with classification 2
# Succesfully Added 2002-04-28, with classification 2
# Succesfully Added 2002-11-09, with classification 2
# Succesfully Added 2002-11-10, with classification 2
# Succesfully Added 2002-11-11, with classification 2
# Succesfully Added 2002-12-18, with classification 2
# Succesfully Added 2002-12-19, with classification 2
# Succesfully Added 2003-02-22, with classification 2
# Succesfully Added 2003-03-20, with classification 2
# Succesfully Added 2003-04-06, with classification 2
# Succesfully Added 2003-04-24, with classification 2
# Succesfully Added 2003-05-04, with classification 2
# Succesfully Added 2003-05-05, with classification 2
# Succesfully Added 2003-05-07, with classification 2
# Succesfully Added 2003-05-11, with classification 2
# Succesfully Added 2003-05-16, with classification 2
# Succesfully Added 2004-01-25, with classification 2
# Succesfully Added 2004-02-05, with classification 2
# Succesfully Added 2004-05-30, with classification 2
# Succesfully Added 2004-08-12, with classification 2
# Succesfully Added 2004-09-15, with classification 2
# Succesfully Added 2004-09-16, with classification 2
# Succesfully Added 2004-09-27, with classification 2
# Succesfully Added 2004-11-24, with classification 2
# Succesfully Added 2004-11-27, with classification 2
# Succesfully Added 2004-12-10, with classification 2
# Succesfully Added 2005-01-07, with classification 2
# Succesfully Added 2005-01-12, with classification 2
# Succesfully Added 2005-01-13, with classification 2
# Succesfully Added 2005-01-14, with classification 2
# Succesfully Added 2005-04-06, with classification 2
# Succesfully Added 2005-07-06, with classification 2
# Succesfully Added 2005-07-07, with classification 2
# Succesfully Added 2005-08-29, with classification 2
# Succesfully Added 2005-09-24, with classification 2
# Succesfully Added 2005-09-25, with classification 2
# Succesfully Added 2005-11-27, with classification 2
# Succesfully Added 2005-12-05, with classification 2
# Succesfully Added 2006-01-02, with classification 2
# Succesfully Added 2006-03-09, with classification 2
# Succesfully Added 2006-04-02, with classification 2
# Succesfully Added 2006-04-07, with classification 2
# Succesfully Added 2006-04-08, with classification 2
# Succesfully Added 2006-05-10, with classification 2
# Succesfully Added 2006-09-22, with classification 2
# Succesfully Added 2006-11-15, with classification 2
# Succesfully Added 2006-12-25, with classification 2
# Succesfully Added 2006-12-31, with classification 2
# Succesfully Added 2007-01-05, with classification 2
# Succesfully Added 2007-01-07, with classification 2
# Succesfully Added 2007-02-24, with classification 2
# Succesfully Added 2007-03-01, with classification 2
# Succesfully Added 2007-04-14, with classification 2
# Succesfully Added 2007-04-15, with classification 2
# Succesfully Added 2007-11-14, with classification 2
# Succesfully Added 2007-12-15, with classification 2
# Succesfully Added 2007-12-20, with classification 2
# Succesfully Added 2008-01-10, with classification 2
# Succesfully Added 2008-02-06, with classification 2
# Succesfully Added 2008-02-17, with classification 2
# Succesfully Added 2008-03-03, with classification 2
# Succesfully Added 2008-03-07, with classification 2
# Succesfully Added 2008-03-14, with classification 2
# Succesfully Added 2008-03-15, with classification 2
# Succesfully Added 2008-04-03, with classification 2
# Succesfully Added 2008-04-04, with classification 2
# Succesfully Added 2008-04-11, with classification 2
# Succesfully Added 2008-05-02, with classification 2
# Succesfully Added 2008-05-08, with classification 2
# Succesfully Added 2008-05-09, with classification 2
# Succesfully Added 2008-05-10, with classification 2
# Succesfully Added 2008-05-11, with classification 2
# Succesfully Added 2008-05-15, with classification 2
# Succesfully Added 2008-08-25, with classification 2
# Succesfully Added 2008-09-03, with classification 2
# Succesfully Added 2008-09-12, with classification 2
# Succesfully Added 2008-12-10, with classification 2
# Succesfully Added 2009-02-18, with classification 2
# Succesfully Added 2009-02-19, with classification 2
# Succesfully Added 2009-02-28, with classification 2
# Succesfully Added 2009-03-26, with classification 2
# Succesfully Added 2009-04-09, with classification 2
# Succesfully Added 2009-04-10, with classification 2
# Succesfully Added 2009-04-19, with classification 2
# Succesfully Added 2009-05-03, with classification 2
# Succesfully Added 2009-05-06, with classification 2
# Succesfully Added 2009-06-12, with classification 2
# Succesfully Added 2009-07-30, with classification 2
# Succesfully Added 2009-10-29, with classification 2
# Succesfully Added 2009-12-02, with classification 2
# Succesfully Added 2009-12-24, with classification 2
# Succesfully Added 2010-01-21, with classification 2
# Succesfully Added 2010-03-10, with classification 2
# Succesfully Added 2010-03-28, with classification 2
# Succesfully Added 2010-04-24, with classification 2
# Succesfully Added 2010-04-25, with classification 2
# Succesfully Added 2010-04-30, with classification 2
# Succesfully Added 2010-05-02, with classification 2
# Succesfully Added 2010-10-25, with classification 2
# Succesfully Added 2010-11-29, with classification 2
# Succesfully Added 2010-12-31, with classification 2
# Succesfully Added 2011-01-01, with classification 2
# Succesfully Added 2011-02-24, with classification 2
# Succesfully Added 2011-02-28, with classification 2
# Succesfully Added 2011-03-05, with classification 2
# Succesfully Added 2011-03-09, with classification 2
# Succesfully Added 2011-03-23, with classification 2
# Succesfully Added 2011-04-04, with classification 2
# Succesfully Added 2011-04-15, with classification 2
# Succesfully Added 2011-04-25, with classification 2
# Succesfully Added 2011-05-25, with classification 2
# Succesfully Added 2011-05-26, with classification 2
# Succesfully Added 2011-11-16, with classification 2
# Succesfully Added 2011-12-22, with classification 2
# Succesfully Added 2012-01-11, with classification 2
# Succesfully Added 2012-01-22, with classification 2
# Succesfully Added 2012-01-23, with classification 2
# Succesfully Added 2012-02-24, with classification 2
# Succesfully Added 2012-03-02, with classification 2
# Succesfully Added 2012-03-03, with classification 2
# Succesfully Added 2012-03-21, with classification 2
# Succesfully Added 2012-04-26, with classification 2
# Succesfully Added 2012-08-30, with classification 2
# Succesfully Added 2012-10-17, with classification 2
# Succesfully Added 2013-01-30, with classification 2
# Succesfully Added 2013-02-10, with classification 2
# Succesfully Added 2013-02-21, with classification 2
# Succesfully Added 2013-03-18, with classification 2
# Succesfully Added 2013-04-10, with classification 2
# Succesfully Added 2013-04-11, with classification 2
# Succesfully Added 2013-04-19, with classification 2
# Succesfully Added 2013-04-27, with classification 2
# Succesfully Added 2013-09-20, with classification 2
# Succesfully Added 2013-12-21, with classification 2
# Succesfully Added 2014-02-21, with classification 2
# Succesfully Added 2014-04-07, with classification 2
# Succesfully Added 2014-04-27, with classification 2
# Succesfully Added 2014-04-28, with classification 2
# Succesfully Added 2014-10-13, with classification 2
# Succesfully Added 2014-11-17, with classification 2
# Succesfully Added 2014-12-29, with classification 2
# Succesfully Added 2015-01-03, with classification 2
# Succesfully Added 2015-01-04, with classification 2
# Succesfully Added 2015-04-19, with classification 2
# Succesfully Added 2015-09-24, with classification 2
# Succesfully Added 2015-12-23, with classification 2
# Succesfully Added 2015-12-25, with classification 2
# Succesfully Added 2015-12-28, with classification 2
# Succesfully Added 2016-01-21, with classification 2
# Succesfully Added 2016-02-15, with classification 2
# Succesfully Added 2016-03-31, with classification 2
# Succesfully Added 2016-04-06, with classification 2
# Succesfully Added 2016-04-07, with classification 2
# Succesfully Added 2016-11-30, with classification 2
# Succesfully Added 2017-01-02, with classification 2
# Succesfully Added 2017-01-19, with classification 2
# Succesfully Added 2017-01-21, with classification 2
# Succesfully Added 2017-01-22, with classification 2
# Succesfully Added 2017-02-09, with classification 2
# Succesfully Added 2017-03-24, with classification 2
# Succesfully Added 2017-03-29, with classification 2
# Succesfully Added 2017-04-02, with classification 2
# Succesfully Added 2017-04-03, with classification 2
# Succesfully Added 2017-04-05, with classification 2
# Succesfully Added 2017-04-27, with classification 2
# Succesfully Added 2017-04-30, with classification 2
# Succesfully Added 2017-05-24, with classification 2
# Succesfully Added 2017-08-31, with classification 2
# Succesfully Added 2017-10-08, with classification 2
# Succesfully Added 2017-10-23, with classification 2
# Succesfully Added 2018-03-11, with classification 2
# Succesfully Added 2018-03-19, with classification 2
# Succesfully Added 2018-04-13, with classification 2
# Succesfully Added 2018-04-14, with classification 2
# Succesfully Added 2018-04-15, with classification 2
# Succesfully Added 2018-06-22, with classification 2
# Succesfully Added 2018-10-31, with classification 2
# Succesfully Added 2018-11-01, with classification 2
# Succesfully Added 2018-11-05, with classification 2
# Succesfully Added 2018-12-02, with classification 2
# Succesfully Added 2019-01-19, with classification 2
# Succesfully Added 2019-02-23, with classification 2
# Succesfully Added 2019-03-03, with classification 2
# Succesfully Added 2019-03-14, with classification 2
# Succesfully Added 2019-04-13, with classification 2
# Succesfully Added 2019-04-18, with classification 2
# Succesfully Added 2019-04-19, with classification 2
# Succesfully Added 2019-04-25, with classification 2
# Succesfully Added 2019-06-06, with classification 2
# Succesfully Added 2019-12-16, with classification 2
# Finished!

# %%
merged_ds = pd.concat([df1, df2,df0])
merged_ds.to_csv('labeled_dates.csv')

# %%
tor_df = pd.read_csv("/home/z1995995/data_science_for_the_geosciences/495/1950-2023_actual_tornadoes.csv")

# %%
x = xr.open_dataset('/home/scratch/ahaberlie1/gefs_reforecast_preproc/200212301200_daily_preproc_ml.nc')

# %%
available_dates
# Out:
# set()

# %%
x = pd.read_csv('/home/scratch/BWEART2/tor_RF_event_valuess.csv'
# Out:
#            date     u10_sum     v10_sum      t2m_sum    td2m_sum    cprec_sum  \
# 0    2001-03-12   1658.5000   3126.8125   53229.4375  30633.6250  2699.447510
# 1    2001-06-18   4309.3750   5492.0625  116152.9375  79823.4375  9155.352539
# 2    2001-10-11   3332.1250  10315.1250  103223.1875  74876.1250  4459.046875
# 3    2001-12-07  10383.0000   7104.1875   68248.2500  47934.9375  1929.285522
# 4    2002-10-12  -1711.0625   3175.0000   95548.0000  66360.8125  4568.133789
# ..          ...         ...         ...          ...         ...          ...
# 145  2017-12-01   1239.8125  -2166.3750   54707.8125  18284.8750   246.613403
# 146  2018-12-13   5490.3125  12453.2500   49544.0000  40483.3750  2597.056152
# 147  2019-02-01  -1066.0000   -478.1875   18524.6875   -301.0000   641.876648
# 148  2019-03-10  11960.7500  11954.9375   61323.6875  47689.1875  8396.304688
# 149  2019-12-04  12595.5000   3874.3125   43717.3750  16586.0000   153.914978
#
#      srh500m_sum   srh1km_sum    srh3km_sum      scp_sum  ...  scp_median  \
# 0    242782.3750  470657.7500  9.033891e+05   582.496094  ...    0.002930
# 1     98686.5625  188018.6875  3.083128e+05  1044.048828  ...    0.000000
# 2    243918.5625  329878.5625  4.414451e+05  2553.470703  ...    0.130859
# 3    299024.0000  445511.4375  7.337777e+05   185.726562  ...    0.006836
# 4    156487.7500  271566.2500  4.016329e+05   691.721680  ...    0.004883
# ..           ...          ...           ...          ...  ...         ...
# 145  124709.7500  247255.1250  5.299416e+05    52.013672  ...    0.000000
# 146  704249.1875  983862.6250  1.322796e+06   673.649414  ...    0.034180
# 147  362393.1250  662622.3125  1.082120e+06    84.563477  ...    0.000000
# 148  452903.0000  754821.6875  1.159126e+06  1064.243164  ...    0.081055
# 149  240868.5000  350035.3750  6.786561e+05    43.528320  ...    0.000000
#
#      stp_median  vtp_median  lcl_median  shear6km_median  mslp_median  \
# 0     -0.000000        -0.0    857.1875          27.0000    1021.6250
# 1      0.000000        -0.0   1432.7500          10.0000    1018.5000
# 2      0.000000        -0.0   1018.1875          13.0000    1020.7500
# 3      0.000977         0.0    927.4375          27.0000    1023.8750
# 4      0.000000        -0.0   1044.7500          13.0625    1021.3125
# ..          ...         ...         ...              ...          ...
# 145    0.000000         0.0   1387.2500          23.3125    1026.5625
# 146    0.000977        -0.0    352.4375          27.0000    1017.4375
# 147   -0.000000         0.0    794.9375          27.0000    1031.1875
# 148    0.002930         0.0    614.6875          27.0000    1018.1875
# 149    0.000000         0.0   1112.2500          27.0000    1018.6875
#
#      pwat_median  sbcape_median  sbcin_median  classification
# 0        20.0000            6.0        0.0625               1
# 1        41.6875         1290.0       -0.2500               1
# 2        39.6875         1091.0       -0.0625               1
# 3        28.5000            6.0        0.1875               1
# 4        35.6250           98.0        0.3125               1
# ..           ...            ...           ...             ...
# 145      11.5000            0.0        0.2500               0
# 146      25.3750            2.0        0.0625               0
# 147      16.1250            0.0        0.2500               0
# 148      31.6875           12.0        0.0625               0
# 149      14.6250            0.0        0.1875               0
#
# [150 rows x 36 columns]

# %%
import sklearn


x = pd.read_csv('/home/scratch/BWEART2/tor_RF_event_values_all.csv')
# Out:
#             date     u10_sum     v10_sum      t2m_sum    td2m_sum  \
# 0     2001-01-01   3089.0000   1629.6250   22348.6250   6275.7500
# 1     2001-01-03   8393.8750   4435.5000   16879.4375 -10549.2500
# 2     2001-01-04  16911.5625   4798.5625   19100.6875    -38.3125
# 3     2001-01-05  16051.3125   5553.1250   10161.3750 -13502.0625
# 4     2001-01-06  11679.5625   5083.6875   16171.8125  -4193.5625
# ...          ...         ...         ...          ...         ...
# 5872  2019-04-18   8819.5000  21023.0000   88414.3750  64963.8750
# 5873  2019-04-19  18047.0625  15793.2500   79430.8750  54960.8750
# 5874  2019-04-25   9165.1250  12443.8125   89505.6875  63057.9375
# 5875  2019-06-06   7297.6875   3106.4375  115063.9375  77039.1250
# 5876  2019-12-16   8956.7500   1592.5000   31713.2500   6125.5000
#
#         cprec_sum  srh500m_sum   srh1km_sum    srh3km_sum      scp_sum  ...  \
# 0      877.676453  381578.5000  629752.3125  1.067620e+06   128.050781  ...
# 1       77.194946  363948.5625  528811.0000  8.707932e+05    29.475586  ...
# 2      435.279785  423530.6250  644313.8125  1.119882e+06    59.402344  ...
# 3      147.988342  481445.5625  656719.8125  1.023956e+06    18.549805  ...
# 4      389.186462  440460.6250  631692.6875  1.022756e+06    57.415039  ...
# ...           ...          ...          ...           ...          ...  ...
# 5872  8550.261719  571568.1250  793386.6250  1.082325e+06  5221.807617  ...
# 5873  7135.784668  398923.9375  582328.8750  9.750844e+05  3545.743164  ...
# 5874  5615.302734  321854.3125  417810.0000  6.222134e+05  2773.565430  ...
# 5875  5384.512695  110655.0000  204620.2500  3.417985e+05  1315.011719  ...
# 5876   795.573853  248854.6875  452709.8125  8.196742e+05    48.195312  ...
#
#       scp_median  stp_median  vtp_median  lcl_median  shear6km_median  \
# 0       0.000000    0.000000        -0.0    624.3750          27.0000
# 1       0.000000    0.000000         0.0   1157.3750          27.0000
# 2       0.000000    0.000000         0.0    754.5625          27.0000
# 3       0.000000   -0.000000        -0.0   1035.3750          27.0000
# 4       0.000000   -0.000000        -0.0    958.6250          27.0000
# ...          ...         ...         ...         ...              ...
# 5872    0.644531    0.088867        -0.0    921.0625          27.0000
# 5873    0.265625    0.025391        -0.0   1003.9375          27.0000
# 5874    0.333984    0.013672        -0.0    983.5000          19.6875
# 5875    0.005859   -0.000000        -0.0   1494.2500          11.1875
# 5876    0.000000    0.000000         0.0   1013.9375          27.0000
#
#       mslp_median  pwat_median  sbcape_median  sbcin_median  classification
# 0       1028.1875      18.3125            0.0        0.1875               0
# 1       1029.1875      10.1250            0.0        0.1250               0
# 2       1024.1250       9.8125            3.0        0.1875               0
# 3       1023.5625       9.1875            0.0        0.2500               0
# 4       1023.6875      10.5000            0.0        0.1875               0
# ...           ...          ...            ...           ...             ...
# 5872    1011.0625      37.1875          327.0        0.0000               2
# 5873    1012.0625      31.8125          111.0        0.0000               2
# 5874    1015.6875      32.6875          350.0        0.0625               2
# 5875    1013.0000      44.8125          976.0       -0.0000               2
# 5876    1024.2500      12.1250            0.0        0.3125               2
#
# [5877 rows x 36 columns]
